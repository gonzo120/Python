# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/sao/Desktop/Python/Datascience/datasets/train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Llamamos una posicion especifica
df['LotArea'][1456]
# Out:
# 13175

# %%
#rangos
df['LotArea']>10000
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1455    False
# 1456     True
# 1457    False
# 1458    False
# 1459    False
# Name: LotArea, Length: 1460, dtype: bool

# %%
#filtrar informacion mayores a 20000 en LotArea
filtrar = df['LotArea'] >20000
df_filtrados = df[filtrar]
df_filtrados
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 53      54          20       RL         68.0    50271   Pave   NaN      IR1
# 113    114          20       RL          NaN    21000   Pave   NaN      Reg
# 120    121          80       RL          NaN    21453   Pave   NaN      IR1
# 171    172          20       RL        141.0    31770   Pave   NaN      IR1
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 271    272          20       RL         73.0    39104   Pave   NaN      IR1
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 349    350          60       RL         56.0    20431   Pave   NaN      IR2
# ...

# %%
#atributos de un dataframe
#df.info(): devuelve informacion(numero de filas, numero de columnas,indices, tipo de columnas y memoria usado)
#df.shape: devuelve una tupla con el numero de filas y columnas de DataFrame.
#df.size: devuelve el numero de elementos del DataFrame
#df.columns: Devuelve una lista con los nombres de las columnas del DataFrame
#df.index: Devuelve una lista con los nombres de las filas del DataFrame
#df.dtypes: Devuelve una serie con los tipos de datos de las columnas del DataFrame
#df.head(n): devuelve el n primeras filas del DataFrame
#df.tail(n) devuelve las n ultimas filas del DataFrame df.

# %%
df_filtrados.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1260  1261          60       RL          NaN    24682   Pave   NaN      IR3
# 1270  1271          40       RL          NaN    23595   Pave   NaN      Reg
# 1287  1288          20       RL          NaN    36500   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1346  1347          20       RL          NaN    20781   Pave   NaN      IR2
# 1383  1384          30       RL          NaN    25339   Pave   NaN      Reg
# 1396  1397          20       RL          NaN    57200   Pave   NaN      IR1
# 1409  1410          60       RL         46.0    20544   Pave   NaN      IR1
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
df_filtrados.shape
# Out:
# (53, 81)
