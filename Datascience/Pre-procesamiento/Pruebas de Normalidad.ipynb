# %%
import numpy as np
import matplotlib.pylab as plt
data_points = np.random.normal(0,1,100) 
data_points
# Out:
# array([ 1.36719917,  0.08701685,  0.78305647, -0.24463169,  1.33627105,
#        -1.71735529, -1.16720359,  0.36034823,  0.21869001,  0.33636796,
#        -0.17066681, -0.19076541,  0.9010458 ,  0.34421139, -1.79072025,
#         1.08564057, -2.46187846, -0.18838556,  1.02916305,  0.78576819,
#        -0.27950927,  0.32312836,  1.42132737,  0.94086845, -1.26292036,
#         0.50940088, -0.44865013, -0.40351407, -0.39864619,  0.16881495,
#         1.31586281, -0.49819834,  0.99459401, -0.58960959, -0.56469137,
#         0.68514141,  0.01961556, -0.80305538, -1.18855059, -0.79959262,
#         0.670723  ,  1.69317416, -0.42356144,  0.08815298, -0.44467803,
#        -0.6558885 , -0.00330878,  0.36204086, -0.67273501, -0.47779612,
#         0.53290356,  0.77660288, -1.9611768 ,  0.41520919,  2.19214296,
#        -0.79430818,  0.989889  , -2.41448725, -0.26346277, -0.07749367,
#        -1.09000244,  0.60611896, -0.3976227 ,  0.97386218,  0.87643735,
#        -0.45478796, -0.88922197,  0.37747915,  0.24079482, -0.10144732,
#        -0.08888608, -0.36091268, -0.42521611,  1.08256861, -0.00787078,
#        -0.30767917, -0.68645744, -0.47467683,  0.3649576 , -1.21681313,
#        -0.84460673,  0.93784614,  1.29770839,  0.45710207,  0.39880828,
#         1.58867628,  0.52199591, -1.11275097, -0.98042281,  0.64052723,
#         0.31440248,  0.08376364, -1.7817073 ,  1.1551713 , -0.00511288,
#         1.04725929, -0.84600322,  0.53820083,  0.46016623,  1.27962539])

# %%
#Creamos el histograma con los datos generados aleatoriamente
plt.hist(data_points, edgecolor = 'black', linewidth=1)
# Out:
# (array([ 2.,  4.,  6., 10., 21., 15., 21., 12.,  8.,  1.]),
#  array([-2.46187846, -1.99647632, -1.53107418, -1.06567203, -0.60026989,
#         -0.13486775,  0.33053439,  0.79593654,  1.26133868,  1.72674082,
#          2.19214296]),
#  <BarContainer object of 10 artists>)

# %%
import pylab
import scipy.stats as stats

stats.probplot(data_points, dist="norm", plot=pylab)
pylab.show()
