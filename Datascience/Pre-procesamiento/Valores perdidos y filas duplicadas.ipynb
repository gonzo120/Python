# %% [markdown]
# # Deteccion de valores perdidos y de valores duplicados

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/sao/Desktop/Python/Datascience/datasets/Niveles de contaminacion.csv')
df.head()
# Out:
#    Numero_de_empresas  PM10   PM2.5       SO2    CO      NOX    COV  NH3  \
# 0                   0   945   629.0    1814.0   235    843.0   1836   14
# 1                 588  1978  1842.0    5588.0  6850      NaN  11692  254
# 2                  27  1028   752.0   22890.0   505      NaN    516  115
# 3                  39  4527  3847.0  574973.0  8698  34132.0   3465  382
# 4                 214  5063  3083.0   54592.0  2510   4845.0   3419  912
#
#       CN
# 0    5.0
# 1    NaN
# 2   58.0
# 3  356.0
# 4  812.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PM10    33 non-null     int64
#  1   PM2.5   29 non-null     float64
#  2   SO2     32 non-null     float64
#  3   CO      33 non-null     int64
#  4   NOX     25 non-null     float64
#  5   COV     33 non-null     int64
#  6   NH3     33 non-null     int64
#  7   CN      25 non-null     float64
# dtypes: float64(4), int64(4)
# memory usage: 2.3 KB

# %%
#contamos si se tienen valores perdidos
df.isnull().sum()
# Out:
# PM10     0
# PM2.5    4
# SO2      1
# CO       0
# NOX      8
# COV      0
# NH3      0
# CN       8
# dtype: int64

# %%
df1 = pd.read_csv('C:/Users/sao/Desktop/Python/Datascience/datasets/Patron de Compra con NAs.csv', index_col=0)
df1
# Out:
#           Estado_Civil  Profesion Estudios_Univ Tiene_Auto Compra
# IdCliente
# 1               Casado  Empresari            Si         No     No
# 2               Casado  Empresari            Si         Si     No
# 3                  NaN  Empresari            Si        NaN     Si
# 4                Viudo   Desemple            Si         No     Si
# 5                Viudo   Empleado            No         No     Si
# 6                Viudo        NaN            No         Si     No
# 7              Soltero   Empleado            No         Si     Si
# 8               Casado   Desemple            Si         No     No
# 9               Casado   Empleado            No         No     Si
# 10               Viudo   Desemple            No        NaN     Si
# 11                 NaN   Desemple            No         Si     Si
# 12             Soltero   Desemple            Si         Si     No
# 13             Soltero  Empresari            No         No     Si
# ...

# %%
#quitamos los valores perdidoas en las filas
df1_SVP = df1.dropna() #SVP sin valores perdidos
df1_SVP
# Out:
#           Estado_Civil  Profesion Estudios_Univ Tiene_Auto Compra
# IdCliente
# 1               Casado  Empresari            Si         No     No
# 2               Casado  Empresari            Si         Si     No
# 4                Viudo   Desemple            Si         No     Si
# 5                Viudo   Empleado            No         No     Si
# 7              Soltero   Empleado            No         Si     Si
# 8               Casado   Desemple            Si         No     No
# 9               Casado   Empleado            No         No     Si
# 12             Soltero   Desemple            Si         Si     No
# 13             Soltero  Empresari            No         No     Si

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     Numero_de_empresas   PM10    PM2.5       SO2      CO       NOX    COV  \
# 0                    0    945    629.0    1814.0     235     843.0   1836
# 1                  588   1978   1842.0    5588.0    6850       NaN  11692
# 2                   27   1028    752.0   22890.0     505       NaN    516
# 3                   39   4527   3847.0  574973.0    8698   34132.0   3465
# 4                  214   5063   3083.0   54592.0    2510    4845.0   3419
# 5                   34   3360      NaN   33287.0    9505   11015.0   4741
# 6                   42  19963  16177.0  190970.0   24171  158743.0   6202
# 7                  367   8207   4958.0  166476.0    1767   20578.0   1296
# 8                 1569   1381    826.0     699.0     766    2217.0  21967
# 9                   80   2971      NaN   27144.0    2930    6645.0   3156
# 10                 233   3810   2770.0   48462.0   74299    9249.0  10155
# 11                   8   8215   7725.0  104172.0    2327   11206.0    708
# ...
